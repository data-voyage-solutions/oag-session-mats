# %% [markdown]
# # Connecting to a database

# %%
# import the needed libraries
import pandas as pd
from sqlalchemy import create_engine
import pandas.io.sql as sqlio

pd.options.display.max_columns = None

# Create connection to external DB (using sqlalchemy)
# SYNTAX: engine = create_engine('dbengine+driver_optional://myusername:mypassword@hostname:port/dbname')
engine = create_engine('postgresql://un:pw@test-oag-db.cknjqxktq50p.us-east-2.rds.amazonaws.com:5432/oag_HMDA_Loan_Application')

# Put query results into a dataframe
sql = "SELECT * FROM tester_tab;"
dat = sqlio.read_sql_query(sql, engine)

# Turn off connection
engine = None

dat.head()
# Out:
#       index  As of Year Respondent ID  Agency Code  Loan Type  Property Type  \
# 0   5322939        2016    0000011065            5          1              1
# 1   8801353        2016    26-4599244            7          1              1
# 2   1723274        2016    22-3039688            9          3              1
# 3   9491841        2016    13-6131491            7          3              1
# 4  10197863        2016    42-1554181            7          1              1
#
#    Loan Purpose  Occupancy  Loan Amount  Preapproval  Action Type MSA/MD  \
# 0             1          1          840            3            3  19740
# 1             3          1          200            3            3  NA
# 2             3          1          273            3            1  40140
# 3             3          1          152            3            6  17300
# 4             1          1          243            3            1  19124
#
# ...

# %% [markdown]
# ---
# # The Megan Challenge
#
# - Create a `test.zip` file
# - Add some contents. A mix of files? Several files with the same extension?
# - Use the first solution on this stackoverflow thread to test your .zip file out:
# > https://stackoverflow.com/questions/44575251/reading-multiple-files-contained-in-a-zip-file-with-pandas
#
#
# __We want to answer: When using `.read_csv()` with a zip file that contains more than one file, how does it work? How about a zip file comprised of mixed file types?__
#
# ---

# %%
import pandas as pd

# %%
df = pd.read_excel('Allcounties.')

# %% [markdown]
# ---
# # Common Data Prep/Cleaning Tasks using Pandas/Python

# %%
# basic DataFrame operations
df.head()
df.tail()
df.shape
df.columns
df.Index

# selecting columns
df.column_name
df['column_name']

# renaming columns
df.rename({'old_name':'new_name'}, inplace=True)
df.columns = ['new_column_a', 'new_column_b']

# notable columns operations
df.describe() # five number summary
df.column_name.nunique() # number of unique values
df.column_name.value_counts() # number of occurrences of each value in column

# filtering
df[df.column_name < 50] # filter column to be less than 50

# sorting
df.sort_values(by='column_name', ascending = False) # sort biggest to smallest
